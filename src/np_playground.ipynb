# %%
import numpy as np

# %%
counts = [8,1,1,0.1]
np.random.dirichlet(counts, 5)
new_counts = np.array(counts) + 1
np.random.dirichlet(new_counts, 5)
p = new_counts / np.sum(new_counts)
p
# Out:
# array([0.63829787, 0.14184397, 0.14184397, 0.07801418])

# %%
t = (3,4,5)
print(t + (1,2))
# Out:
# (3, 4, 5, 1, 2)
